# %%
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings.openai import OpenAIEmbeddings
from langchain_community.embeddings.huggingface import HuggingFaceEmbeddings
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings

# %%
import os
from langchain_community.embeddings import ZhipuAIEmbeddings
import dotenv

dotenv.load_dotenv(dotenv.find_dotenv())
embedding_key = os.getenv("ZHIPUAI_API_KEY")
embedding = ZhipuAIEmbeddings(api_key=embedding_key, model="embedding-3")

# %%
persist_directory = '../vector_db/chroma'
vectordb = Chroma(
    persist_directory=persist_directory,
    embedding_function=embedding
)
print(f"向量库中存储的数量：{vectordb._collection.count()}")
# Out:
# /var/folders/tw/5jgn7f8j74zgq_93zn_8f2n40000gn/T/ipykernel_56971/525054440.py:2: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectordb = Chroma(
# 向量库中存储的数量：32

# %%
question="色彩"
sim_docs = vectordb.similarity_search(question,k=10)
print(f"检索到的内容数：{len(sim_docs)}")
# Out:
# 检索到的内容数：10

# %%
for i, sim_doc in enumerate(sim_docs):
    print(f"检索到的第{i}个内容: \n{sim_doc.page_content}", end="\n--------------\n")
# Out:
# 检索到的第0个内容:
# 探讨不同颜色对情感和心理反应的影响
# --------------
# 检索到的第1个内容:
# 平静、健康和生机，而红色则带有激情、活力和紧迫感。这种组合常用于健康和
# 生活方式产品的设计。
# - **心理效应：** 绿红的对比使得设计更为生动，能够吸引用户的注意力。在
# 一些环保或有机产品的包装设计中，这种组合常被使用。
# 总体而言，互补色的使用能够产生强烈的对比效果，引起观者的视觉兴奋。然
# 而，设计师需要根据品牌形象、产品定位以及目标受众的喜好来决定是否采用互
# 补色，以确保色彩选择符合整体设计的目标，创造出期望的情感和心理效应。
# 以实际例子说明如何运用颜色传达产品或品牌的情感共鸣
# 行业潮流
# 讨论行业潮流和趋势对包装设计颜色选择的影响
# --------------
# 检索到的第2个内容:
# 不同颜色对情感和心理反应的影响是色彩心理学的一个重要研究领域。各种颜色
# 都能够激发人们不同的情绪和心理状态，因此，在包装设计中选择合适的颜色是
# 至关重要的。以下是一些常见颜色对情感和心理反应的一般影响：
# 1. **红色：**
# - **激情和兴奋：** 红色通常与活力、激情和兴奋相关。它能够引起注意，传
# 达紧急感，并激发人们的兴奋和冲动。
# 2. **蓝色：**
# - **冷静和信任：** 蓝色通常被认为是冷静、深思熟虑的颜色，有助于传达信
# 任和可靠感。在包装中使用蓝色可能使消费者感到安心和放松。
# 3. **绿色：**
# - **平静和健康：** 绿色与大自然、生机和健康相关联。它可以传递平静的感
# 觉，以及对环保和可持续性的关注。
# 4. **黄色：**
# - **愉悦和活力：** 黄色是一种明亮、愉悦的颜色，能够引发积极的情绪和活
# 力。它常常用于传达快乐、温暖和乐观的氛围。
# 5. **紫色：**
# - **奢华和神秘：** 紫色通常与奢华、优雅和神秘感联系在一起。在一些高端
# 产品的包装设计中，紫色可以传递豪华和独特性。
# 6. **橙色：**
# --------------
# 检索到的第3个内容:
# 行业潮流和趋势对包装设计颜色选择有着深远的影响。颜色在设计中是一个重要
# 的视觉元素，它需要紧密跟随社会文化、消费者偏好和行业发展的变化。以下是
# 行业潮流和趋势对包装设计颜色选择的影响：
# 1. **反映消费者价值观的演变：** 随着社会的发展和消费者价值观的演变，包
# 装颜色选择往往会受到这些变化的影响。例如，对可持续性和环保的关注在近年
# 来不断增加，因此一些行业在包装设计中选择更多与自然相关的绿色、蓝色等颜
# 色，以反映出品牌的环保理念。
# 2. **时尚和设计趋势的影响：** 包装设计中的颜色选择通常受到时尚和设计趋
# 势的启发。一些颜色可能在一段时间内成为热门，随后可能会被新的颜色或色彩
# 组合取代。跟随时尚趋势有助于确保产品在市场上显得新颖和时尚。
# 3. **数字化媒体和社交平台的影响：** 在数字化时代，社交媒体和在线平台对
# 于信息传播至关重要。颜色在屏幕上的呈现可能与印刷品不同，因此设计师可能
# 会更倾向于选择在数字媒体上更吸引眼球的颜色。
# 4. **品牌创新和个性化：** 一些行业可能选择采用独特和创新的颜色来突显品
# --------------
# 检索到的第4个内容:
# - **趋势特点：** 在一些年轻、时尚、娱乐性强的产品上，多彩和鲜艳的配色
# 成为吸引年轻消费者的选择。
# - **案例：** 一些饮料、零食或儿童产品的包装设计中，使用了明亮的颜色，
# 吸引目标受众的注意力。这可以包括彩虹色调或梦幻般的配色。
# ### 4. **高科技和数码元素趋势：**
# - **趋势特点：** 在科技产品领域，一些品牌选择采用霓虹光效果、数字图形
# 和金属质感的颜色，以突显高科技和现代感。
# - **案例：** 电子产品的包装设计中，可能使用了金属质感的颜色如银色或金
# 色，结合数字化的元素，创造出时尚和科技感。
# ### 5. **个性化和定制化趋势：**
# - **趋势特点：** 一些品牌通过个性化的色彩选择，强调独特性，满足消费者
# 对个性和定制化的需求。
# - **案例：** 定制化商品或特殊活动的包装设计中，可能会采用与品牌标志性
# 颜色不同的独特颜色，以突显个性化和限量版的特质。
# 这些趋势并非绝对，因为颜色选择很大程度上取决于品牌的定位、目标受众以及
# 产品类型。实际的包装设计中，可能会将不同趋势进行组合，以创造出更具吸引
# 力和独特性的包装效果。
# 季节性变化
# --------------
# 检索到的第5个内容:
# 具创意。
# 7. **可视化传达品牌故事：** 颜色在传达品牌故事和价值观方面扮演着重要角
# 色。当前的潮流是将颜色与品牌故事紧密结合，通过色彩传递更加深刻和丰富的
# 品牌信息。
# 总体而言，包装设计颜色选择的潮流和趋势紧密关联着社会、文化和技术的发
# 展。了解并跟随行业潮流，同时保持品牌的独特性，对于设计师来说是一个平衡
# 的挑战，但也是创造成功包装设计的关键。
# 通过案例分析最新潮流在包装设计中的应用
# --------------
# 检索到的第6个内容:
# 包装设计
# 引言
# 介绍包装设计中颜色应用的重要性
# 提及色彩原理与运用的学习背景
# 品牌色彩一致性
# 解释为何品牌色彩一致性对于包装设计至关重要
# 品牌色彩一致性对于包装设计的重要性在于它建立了品牌的视觉识别度和记忆效
# 应，为消费者提供了一种直观、一致的品牌体验。以下是品牌色彩一致性在包装
# 设计中的关键作用：
# 1. **品牌辨识度：** 一致的品牌色彩使得品牌在市场上更易辨认。消费者在购
# 物时经常受到大量商品和广告的影响，品牌色彩的一致性有助于产品在瞬息万变
# 的市场环境中脱颖而出，使消费者能够迅速辨认和选择自己信任的品牌。
# 2. **情感共鸣：** 品牌色彩往往与品牌的价值观和情感共鸣相关联。通过一致
# 的色彩，品牌可以传达其个性、文化和对消费者的承诺，建立起一种与目标受众
# 之间的情感联系。这种情感共鸣有助于消费者与品牌建立深层次的关系，提高品
# 牌忠诚度。
# 3. **品牌记忆效应：** 一致的品牌色彩有助于形成品牌记忆效应。当消费者反
# 复在不同场合中看到相同的品牌色彩时，这些颜色就会与品牌名称、标志和产品
# 联系在一起，形成深刻的印象。这种品牌记忆效应使得消费者更容易回想起品
# --------------
# 检索到的第7个内容:
# 牌忠诚度。
# 3. **品牌记忆效应：** 一致的品牌色彩有助于形成品牌记忆效应。当消费者反
# 复在不同场合中看到相同的品牌色彩时，这些颜色就会与品牌名称、标志和产品
# 联系在一起，形成深刻的印象。这种品牌记忆效应使得消费者更容易回想起品
# 牌，从而提高再次购买的可能性。
# 4. **信任和可靠性：** 一致的品牌色彩传递了品牌的专业性和可靠性。在消费
# 者心目中，品牌色彩的一致性与品牌的稳定性和质量保证相联系。这种可靠性有
# 助于建立消费者对品牌的信任感，使其更愿意选择该品牌的产品。
# 5. **市场区隔：** 品牌色彩的一致性有助于在竞争激烈的市场中实现有效的区
# 隔。通过巩固独特的品牌色彩，品牌能够在消费者心中建立起独特的地位，从而
# 在同类产品中脱颖而出。
# 6. **广告和促销效果：** 一致的品牌色彩使得广告和促销活动更具效果。在各
# 种媒体上展示一致的品牌色彩，有助于提高广告的辨识度和记忆效应，增加广告
# 观众的对品牌的信任度。
# 总体而言，品牌色彩的一致性不仅仅是一种视觉上的统一，更是品牌建设和市场
# 传播中的战略选择。在包装设计中，通过巧妙运用品牌色彩一致性，品牌可以在
# --------------
# 检索到的第8个内容:
# 信任和专业感联系，而橙色则带有活力、温暖和乐观的情感。这种组合常用于传
# 达科技、创新和活力。
# - **心理效应：** 蓝橙的对比既能够创造出引人注目的设计，又能够在视觉上
# 保持相对平衡。这种组合通常给人一种现代感和时尚感。
# 3. **黄紫：**
# - **情感表达：** 黄紫是一种明亮且鲜艳的互补色组合。黄色通常与愉悦、活
# 力和乐观联系在一起，而紫色则与奢华、神秘感关联。这种组合常用于传递富有
# 创意和独特性的品牌形象。
# - **心理效应：** 黄紫的组合能够吸引视线，给人一种艺术感和独特感。在设
# 计中适度使用，可以营造出充满活力和创造力的氛围。
# 4. **绿红：**
# - **情感表达：** 绿红是一种生机盎然且引人注目的互补色组合。绿色传达出
# 平静、健康和生机，而红色则带有激情、活力和紧迫感。这种组合常用于健康和
# 生活方式产品的设计。
# - **心理效应：** 绿红的对比使得设计更为生动，能够吸引用户的注意力。在
# 一些环保或有机产品的包装设计中，这种组合常被使用。
# 总体而言，互补色的使用能够产生强烈的对比效果，引起观者的视觉兴奋。然
# --------------
# 检索到的第9个内容:
# 3. **数字化媒体和社交平台的影响：** 在数字化时代，社交媒体和在线平台对
# 于信息传播至关重要。颜色在屏幕上的呈现可能与印刷品不同，因此设计师可能
# 会更倾向于选择在数字媒体上更吸引眼球的颜色。
# 4. **品牌创新和个性化：** 一些行业可能选择采用独特和创新的颜色来突显品
# 牌个性，以在竞争激烈的市场中脱颖而出。定制化和个性化的包装设计也是当前
# 市场的一个趋势，颜色选择在其中扮演了关键角色。
# 5. **跨文化设计：** 全球化的市场使得跨文化设计变得更加重要。颜色在不同
# 文化中可能有不同的象征意义，因此行业潮流需要考虑到产品或品牌的国际化和
# 本地化。
# 6. **技术的影响：** 随着印刷和包装技术的不断创新，一些新的颜色和效果得
# 以实现。例如，金属感、霓虹光等效果的出现，使得设计师能够在颜色选择上更
# 具创意。
# 7. **可视化传达品牌故事：** 颜色在传达品牌故事和价值观方面扮演着重要角
# 色。当前的潮流是将颜色与品牌故事紧密结合，通过色彩传递更加深刻和丰富的
# 品牌信息。
# 总体而言，包装设计颜色选择的潮流和趋势紧密关联着社会、文化和技术的发
# --------------
